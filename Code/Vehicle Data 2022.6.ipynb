# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Read in the data. This will be combined into 1 dataframe called df

# %%
df1 = pd.read_csv('https://data.ca.gov/dataset/vehicle-fuel-type-count-by-zip-code/resource/1856386b-a196-4e7c-be81-44174e29ad50/download/vehicle-fuel-type-count-by-zip-code.csv')
df2 = pd.read_csv('https://data.ca.gov/dataset/vehicle-fuel-type-count-by-zip-code/resource/888bbb6c-09b4-469c-82e6-1b2a47439736/download/vehicle-fuel-type-count-by-zip-code.csv')
df3 = pd.read_csv('https://data.ca.gov/dataset/vehicle-fuel-type-count-by-zip-code/resource/4254a06d-9937-4083-9441-65597dd267e8/download/vehicle-fuel-type-count-by-zip-code.csv')
df4 = pd.read_csv('https://data.ca.gov/dataset/vehicle-fuel-type-count-by-zip-code/resource/d304108a-06c1-462f-a144-981dd0109900/download/vehicle-fuel-type-count-by-zip-code.csv')
# Out:
# C:\Users\sheel\AppData\Local\Temp\ipykernel_16664\3466865124.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('https://data.ca.gov/dataset/vehicle-fuel-type-count-by-zip-code/resource/1856386b-a196-4e7c-be81-44174e29ad50/download/vehicle-fuel-type-count-by-zip-code.csv')
# C:\Users\sheel\AppData\Local\Temp\ipykernel_16664\3466865124.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('https://data.ca.gov/dataset/vehicle-fuel-type-count-by-zip-code/resource/888bbb6c-09b4-469c-82e6-1b2a47439736/download/vehicle-fuel-type-count-by-zip-code.csv')
# C:\Users\sheel\AppData\Local\Temp\ipykernel_16664\3466865124.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv('https://data.ca.gov/dataset/vehicle-fuel-type-count-by-zip-code/resource/4254a06d-9937-4083-9441-65597dd267e8/download/vehicle-fuel-type-count-by-zip-code.csv')
# C:\Users\sheel\AppData\Local\Temp\ipykernel_16664\3466865124.py:4: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv('https://data.ca.gov/dataset/vehicle-fuel-type-count-by-zip-code/resource/d304108a-06c1-462f-a144-981dd0109900/download/vehicle-fuel-type-count-by-zip-code.csv')

# %% [markdown]
# Combine the data

# %%
frames = [df1, df2, df3, df4]
df = pd.concat(frames)

# %% [markdown]
# Explore some basic information of the data

# %%
df.head(50)
# Out:
#          Date Zip Code Model Year                      Fuel           Make  \
# 0  2022-01-01    90000       2020                  Gasoline      OTHER/UNK
# 1  2022-01-01    90000       2022                  Gasoline      OTHER/UNK
# 2  2022-01-01    90000      <2008                  Gasoline      OTHER/UNK
# 3  2022-01-01    90000      <2008                  Gasoline      OTHER/UNK
# 4  2022-01-01    90000      <2008                  Gasoline      OTHER/UNK
# 5  2022-01-01    90000      <2008                  Gasoline           FORD
# 6  2022-01-01    90000      <2008                  Gasoline       PLYMOUTH
# 7  2022-01-01    90000      <2008                  Gasoline            GMC
# 8  2022-01-01    90000      <2008                  Gasoline      CHEVROLET
# 9  2022-01-01    90000      <2008                     Other      OTHER/UNK
# 10 2022-01-01    90000      <2008  Diesel and Diesel Hybrid      OTHER/UNK
# 11 2022-01-01    90000      <2008  Diesel and Diesel Hybrid      OTHER/UNK
# 12 2022-01-01    90000      <2008  Diesel and Diesel Hybrid          WHITE
# 13 2022-01-01    90001       2008                  Gasoline      OTHER/UNK
# 14 2022-01-01    90001       2008                  Gasoline      OTHER/UNK
# 15 2022-01-01    90001       2008                  Gasoline      OTHER/UNK
# 16 2022-01-01    90001       2008                  Gasoline           FORD
# 17 2022-01-01    90001       2008                  Gasoline            GMC
# 18 2022-01-01    90001       2008                  Gasoline      CHEVROLET
# 19 2022-01-01    90001       2008                  Gasoline       INFINITI
# 20 2022-01-01    90001       2008                  Gasoline  MERCEDES-BENZ
# 21 2022-01-01    90001       2008                  Gasoline     VOLKSWAGEN
# 22 2022-01-01    90001       2008                  Gasoline          DODGE
# 23 2022-01-01    90001       2008                  Gasoline           JEEP
# 24 2022-01-01    90001       2008                  Gasoline          HONDA
# 25 2022-01-01    90001       2008                  Gasoline          HONDA
# 26 2022-01-01    90001       2008                  Gasoline       CHRYSLER
# 27 2022-01-01    90001       2008                  Gasoline       CADILLAC
# 28 2022-01-01    90001       2008                  Gasoline         NISSAN
# 29 2022-01-01    90001       2008                  Gasoline         TOYOTA
# 30 2022-01-01    90001       2008                  Gasoline         TOYOTA
# 31 2022-01-01    90001       2008                  Gasoline          MAZDA
# 32 2022-01-01    90001       2008                  Gasoline            BMW
# 33 2022-01-01    90001       2008                  Gasoline        HYUNDAI
# 34 2022-01-01    90001       2008                  Gasoline          LEXUS
# 35 2022-01-01    90001       2008                  Gasoline            KIA
# 36 2022-01-01    90001       2008                  Gasoline          SCION
# 37 2022-01-01    90001       2008  Diesel and Diesel Hybrid      OTHER/UNK
# 38 2022-01-01    90001       2008  Diesel and Diesel Hybrid      OTHER/UNK
# 39 2022-01-01    90001       2008  Diesel and Diesel Hybrid      OTHER/UNK
# 40 2022-01-01    90001       2008  Diesel and Diesel Hybrid   FREIGHTLINER
# 41 2022-01-01    90001       2008               Natural Gas      OTHER/UNK
# 42 2022-01-01    90001       2008           Hybrid Gasoline      OTHER/UNK
# 43 2022-01-01    90001       2008           Hybrid Gasoline          HONDA
# 44 2022-01-01    90001       2008           Hybrid Gasoline         TOYOTA
# 45 2022-01-01    90001       2008                 Flex-Fuel      OTHER/UNK
# 46 2022-01-01    90001       2008                 Flex-Fuel      OTHER/UNK
# 47 2022-01-01    90001       2008                 Flex-Fuel      CHEVROLET
# 48 2022-01-01    90001       2009                  Gasoline      OTHER/UNK
# 49 2022-01-01    90001       2009                  Gasoline      OTHER/UNK
#
#     Duty  Vehicles  Energy Consumption (kWh/mile)  \
# 0    1.0         1                          0.015
# 1    1.0         1                          0.015
# 2    2.0        22                          0.015
# 3    1.0        20                          0.015
# 4    NaN        12                          0.015
# 5    1.0        26                          0.015
# 6    1.0        59                          0.015
# 7    1.0        15                          0.015
# 8    1.0        26                          0.015
# 9    1.0         6                          0.000
# 10   2.0        17                          0.018
# 11   1.0         1                          0.018
# 12   2.0        19                          0.018
# 13   2.0        10                          0.015
# 14   1.0        86                          0.015
# 15   NaN        47                          0.015
# 16   1.0        74                          0.015
# 17   1.0        27                          0.015
# 18   1.0        97                          0.015
# 19   1.0        51                          0.015
# 20   1.0        17                          0.015
# 21   1.0        11                          0.015
# 22   1.0        41                          0.015
# 23   1.0        32                          0.015
# 24   1.0       195                          0.015
# 25   NaN        13                          0.015
# 26   1.0        24                          0.015
# 27   1.0        27                          0.015
# 28   1.0       139                          0.015
# 29   1.0       197                          0.015
# 30   NaN        36                          0.015
# 31   1.0        17                          0.015
# 32   1.0        44                          0.015
# 33   1.0        16                          0.015
# 34   1.0        36                          0.015
# 35   1.0        14                          0.015
# 36   1.0        42                          0.015
# 37   2.0        41                          0.018
# 38   1.0         4                          0.018
# 39   NaN         9                          0.018
# 40   2.0        12                          0.018
# 41   1.0         1                          0.020
# 42   1.0        14                          0.025
# 43   1.0        11                          0.025
# 44   1.0        36                          0.025
# 45   1.0         8                          0.015
# 46   NaN        13                          0.015
# 47   1.0        27                          0.015
# 48   2.0         1                          0.015
# 49   1.0        80                          0.015
#
#     Energy Consumption (kWh/year)
# 0                           5.475
# 1                           5.475
# 2                         240.900
# 3                         109.500
# 4                             NaN
# 5                         142.350
# 6                         323.025
# 7                          82.125
# 8                         142.350
# 9                           0.000
# 10                        223.380
# 11                          6.570
# 12                        249.660
# 13                        109.500
# 14                        470.850
# 15                            NaN
# 16                        405.150
# 17                        147.825
# 18                        531.075
# 19                        279.225
# 20                         93.075
# 21                         60.225
# 22                        224.475
# 23                        175.200
# 24                       1067.625
# 25                            NaN
# 26                        131.400
# 27                        147.825
# 28                        761.025
# 29                       1078.575
# 30                            NaN
# 31                         93.075
# 32                        240.900
# 33                         87.600
# 34                        197.100
# 35                         76.650
# 36                        229.950
# 37                        538.740
# 38                         26.280
# 39                            NaN
# 40                        157.680
# 41                          7.300
# 42                        127.750
# 43                        100.375
# 44                        328.500
# 45                         43.800
# 46                            NaN
# 47                        147.825
# 48                         10.950
# 49                        438.000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2589061 entries, 0 to 586232
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Date        object
#  1   Zip Code    object
#  2   Model Year  object
#  3   Fuel        object
#  4   Make        object
#  5   Duty        object
#  6   Vehicles    int64
# dtypes: int64(1), object(6)
# memory usage: 158.0+ MB

# %%
df.describe()
# Out:
#            Vehicles
# count  2.589061e+06
# mean   4.751321e+01
# std    1.560435e+02
# min    1.000000e+00
# 25%    1.100000e+01
# 50%    1.900000e+01
# 75%    4.300000e+01
# max    3.599300e+04

# %%
df.shape
# Out:
# (2589061, 7)

# %% [markdown]
# Check for null values. luckily there are none

# %%
df.isnull().sum()
# Out:
# Date          0
# Zip Code      0
# Model Year    0
# Fuel          0
# Make          0
# Duty          0
# Vehicles      0
# dtype: int64

# %% [markdown]
# Convert the Date column to datetime format for easier reading

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# Get the unique fuel types

# %%
df['Fuel'].unique()
# Out:
# array(['Gasoline', 'Other', 'Diesel and Diesel Hybrid', 'Natural Gas',
#        'Hybrid Gasoline', 'Flex-Fuel', 'Battery Electric',
#        'Plug-in Hybrid', 'Hydrogen Fuel Cell'], dtype=object)

# %% [markdown]
# Get the unique make types

# %%
df['Make'].unique()
# Out:
# array(['OTHER/UNK', 'FORD', 'PLYMOUTH', 'GMC', 'CHEVROLET', 'WHITE',
#        'INFINITI', 'MERCEDES-BENZ', 'VOLKSWAGEN', 'DODGE', 'JEEP',
#        'HONDA', 'CHRYSLER', 'CADILLAC', 'NISSAN', 'TOYOTA', 'MAZDA',
#        'BMW', 'HYUNDAI', 'LEXUS', 'KIA', 'SCION', 'FREIGHTLINER', 'ACURA',
#        'MITSUBISHI', 'RAM', 'AUDI', 'MINI', 'BUICK', 'SUBARU', 'TESLA',
#        'MERCURY', 'LINCOLN', 'PORSCHE', 'VOLVO', 'HUMMER', 'PONTIAC',
#        'OLDSMOBILE', 'SATURN', 'ISUZU', 'JAGUAR', 'SUZUKI', 'LAND ROVER',
#        'GEO', 'FIAT', 'GENESIS', 'SAAB', 'HINO', 'LAMBORGHINI',
#        'ROLLS-ROYCE', 'WORKHORSE', 'INTERNATIONAL', 'AMERICAN LAFRANCE',
#        'NORTH AMERICAN BUS INDUSTRIES', 'PETERBILT',
#        'MOTOR COACH INDUSTRIES', 'NEWFLYER', 'KENWORTH', 'BLUE BIRD',
#        'GILLIG', 'AUTOCAR', 'PIERCE', 'IC BUS', 'NEW FLYER', 'PROTERRA',
#        'NEOPLAN', 'OSHKOSH', 'ORION', 'FWD', 'FLXIBLE TRANSIT COACHES',
#        'MACK', 'TMC GREYHOUND', 'STERLING', 'WHITE/GMC',
#        'PIERCE MANUFACTURING', 'ALFA ROMEO', 'KALMAR', 'PREVOST',
#        'MASERATI', 'BENTLEY', 'FERRARI', 'KOVATCH MOBLIE EQUIPMENT CORP.',
#        'THOMAS BUILT BUSES', 'THOMAS BUS', 'IC BUS LLC', 'SMART',
#        'ASTON MARTIN', 'MITSUBISHI FUSO', 'NOVABUS',
#        'KALMAR INDUSTRIES USA LLC', 'CRANE CARRIER', 'ROADMASTER',
#        'ALEXANDER DENNIS', 'CATERPILLAR', 'SPARTAN', 'VPG', 'AM GENERAL',
#        'WESTERN STAR', 'FLEXIBLE', 'VAN HOOL', 'EMERGENCY ONE',
#        'CAPACITY OF TEXAS INC', 'BLUEBIRD', 'EVOBUS', 'LODAL', 'HME',
#        'ALLIANZ', 'MG', 'CAPACITY', 'POLESTAR', 'SPECIAL CONSTRUCTION',
#        'LOTUS', 'COUNTRY COACH', 'IC BUS, LLC', 'SMITH', 'UD TRUCKS',
#        'Unk', 'TEMSA', 'CROWN COACH INC', 'MAN TRUCK AND BUS CORPORATION',
#        'TROLLEY', 'GEM', 'AMERICAN CUSTOM GOLFCARTS', 'MILES', 'COLUMBIA',
#        'DYMAC VEHICLE GROUP INC', 'CLUB CAR', 'WESTERN GOLF CART', 'EBUS',
#        'TOMBERLIN', 'EZGO'], dtype=object)

# %%
df['Duty'].unique()
# Out:
# array([ 1.,  2., nan])

# %% [markdown]
# Plotting the number of vehicles based on fuel type

# %%
fuel_counts = df.groupby('Fuel')['Vehicles'].sum().reset_index()

# %%
plt.bar(fuel_counts['Fuel'], fuel_counts['Vehicles'])
plt.xticks(rotation=90)
plt.xlabel('Fuel Type')
plt.ylabel('Number of Vehicles')
plt.title('Distribution of Vehicles by Fuel Type')
plt.show()

# %% [markdown]
# determine how many vehicles are of a certain make

# %%
# group the dataset by the 'Make' column and count the number of rows in each group
vehicles_by_make = df.groupby('Fuel').count()['Vehicles'].sort_values(ascending=False)

# print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(vehicles_by_make)
    
    # calculate the total number of vehicles
df['Vehicles'].count()
# Out:
# Fuel
# Gasoline                    1557312
# Diesel and Diesel Hybrid     321224
# Flex-Fuel                    294811
# Hybrid Gasoline              205454
# Plug-in Hybrid                82426
# Battery Electric              79481
# Natural Gas                   23139
# Other                         16426
# Hydrogen Fuel Cell             8788
# Name: Vehicles, dtype: int64
# 2589061

# %% [markdown]
# Lets represent the number of vehicles of a certain make as a ratio or percentage of the total number of vehicles in the dataset

# %%
# Get the count of each make
make_count = df['Make'].value_counts()

# Calculate the percentage of each make
make_percent = make_count / make_count.sum() * 100

# print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(make_percent)
# Out:
# OTHER/UNK                         37.991843
# FORD                               6.300779
# TOYOTA                             6.082746
# CHEVROLET                          4.948126
# HONDA                              3.724709
# NISSAN                             2.636709
# LEXUS                              2.613998
# DODGE                              2.476033
# MERCEDES-BENZ                      2.230847
# BMW                                2.189327
# VOLKSWAGEN                         2.108486
# HYUNDAI                            2.096513
# JEEP                               2.014707
# GMC                                1.925447
# KIA                                1.905247
# MAZDA                              1.897676
# SUBARU                             1.865194
# ACURA                              1.524684
# AUDI                               1.347593
# INFINITI                           1.120522
# RAM                                1.049029
# CHRYSLER                           0.940573
# SCION                              0.918480
# CADILLAC                           0.822885
# MINI                               0.698361
# VOLVO                              0.666458
# TESLA                              0.586004
# BUICK                              0.505396
# PORSCHE                            0.479015
# LAND ROVER                         0.472797
# FREIGHTLINER                       0.470093
# MITSUBISHI                         0.416676
# SATURN                             0.285586
# LINCOLN                            0.280913
# PONTIAC                            0.248662
# Unk                                0.245031
# JAGUAR                             0.196210
# PETERBILT                          0.177053
# INTERNATIONAL                      0.170409
# MERCURY                            0.168517
# ISUZU                              0.163457
# FIAT                               0.142639
# OLDSMOBILE                         0.117301
# SUZUKI                             0.105057
# KENWORTH                           0.103397
# HUMMER                             0.083312
# PLYMOUTH                           0.079179
# WORKHORSE                          0.052529
# SAAB                               0.051061
# GEO                                0.044109
# ALFA ROMEO                         0.028234
# HINO                               0.027771
# MASERATI                           0.019196
# AUTOCAR                            0.018192
# GENESIS                            0.014021
# ROADMASTER                         0.013055
# GILLIG                             0.012862
# MACK                               0.010853
# NEWFLYER                           0.008806
# BLUEBIRD                           0.007841
# SMART                              0.007377
# BLUE BIRD                          0.006759
# FERRARI                            0.006605
# THOMAS BUS                         0.006025
# BENTLEY                            0.005678
# IC BUS, LLC                        0.005253
# STERLING                           0.005021
# SPARTAN                            0.004712
# THOMAS BUILT BUSES                 0.004365
# GEM                                0.003592
# VAN HOOL                           0.002897
# MOTOR COACH INDUSTRIES             0.002858
# PIERCE MANUFACTURING               0.002626
# IC BUS                             0.002511
# ROLLS-ROYCE                        0.002202
# NORTH AMERICAN BUS INDUSTRIES      0.002086
# WESTERN STAR                       0.001970
# IC BUS LLC                         0.001545
# KALMAR                             0.001506
# AMERICAN LAFRANCE                  0.001506
# NEW FLYER                          0.001468
# ORION                              0.001352
# KOVATCH MOBLIE EQUIPMENT CORP.     0.001313
# CRANE CARRIER                      0.001043
# HME                                0.000927
# UD TRUCKS                          0.000927
# KALMAR INDUSTRIES USA LLC          0.000850
# WHITE/GMC                          0.000811
# EVOBUS                             0.000772
# MITSUBISHI FUSO                    0.000772
# FLXIBLE TRANSIT COACHES            0.000772
# PREVOST                            0.000695
# PIERCE                             0.000695
# LAMBORGHINI                        0.000657
# TMC GREYHOUND                      0.000618
# ASTON MARTIN                       0.000579
# NEOPLAN                            0.000541
# ALLIANZ                            0.000463
# MG                                 0.000463
# CLUB CAR                           0.000386
# FLEXIBLE                           0.000386
# COLUMBIA                           0.000309
# WHITE                              0.000309
# CATERPILLAR                        0.000270
# NOVABUS                            0.000270
# CAPACITY                           0.000270
# SMITH                              0.000232
# VPG                                0.000232
# CAPACITY OF TEXAS INC              0.000193
# OSHKOSH                            0.000193
# FWD                                0.000154
# MAN TRUCK AND BUS CORPORATION      0.000154
# AM GENERAL                         0.000154
# SPECIAL CONSTRUCTION               0.000154
# LODAL                              0.000154
# EMERGENCY ONE                      0.000154
# TOMBERLIN                          0.000116
# WESTERN GOLF CART                  0.000116
# ALEXANDER DENNIS                   0.000116
# COUNTRY COACH                      0.000077
# DYMAC VEHICLE GROUP INC            0.000077
# CROWN COACH INC                    0.000077
# TROLLEY                            0.000077
# MILES                              0.000077
# EBUS                               0.000039
# AMERICAN CUSTOM GOLFCARTS          0.000039
# LOTUS                              0.000039
# POLESTAR                           0.000039
# TEMSA                              0.000039
# PROTERRA                           0.000039
# EZGO                               0.000039
# Name: Make, dtype: float64

# %% [markdown]
# Lets represent the number of vehicles of a certain Fuel type as a ratio or percentage of the total number of vehicles in the dataset.

# %%
# count the number of vehicles for each fuel type
vehicles_by_fuel = df.groupby('Fuel').count()['Vehicles'].sort_values(ascending=False)

# calculate the total number of vehicles
total_vehicles = df['Vehicles'].count()

# calculate the percentage of vehicles for each fuel type
percentages = (vehicles_by_fuel / total_vehicles) * 100

# print the results
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(percentages)
# Out:
# Fuel
# Gasoline                    60.149684
# Diesel and Diesel Hybrid    12.406969
# Flex-Fuel                   11.386792
# Hybrid Gasoline              7.935464
# Plug-in Hybrid               3.183625
# Battery Electric             3.069877
# Natural Gas                  0.893722
# Other                        0.634439
# Hydrogen Fuel Cell           0.339428
# Name: Vehicles, dtype: float64

# %%
plt.figure(figsize=(10, 8)) # set the size of the figure
# group the data by fuel type and count the number of vehicles
fuel_counts = df.groupby('Fuel')['Vehicles'].count().reset_index()

# plot the distribution of fuel types using a pie chart


plt.figure(figsize=(10, 8))
plt.pie(fuel_counts['Vehicles'], labels=fuel_counts['Fuel'], autopct='%1.1f%%', textprops={'fontsize': 12})
plt.title('Distribution of Fuel Types in the Dataset', fontsize=16)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define energy consumption values (kWh/mile) for each fuel type
energy_consumption = {'Gasoline': 0.015, 'Other': 0, 'Diesel and Diesel Hybrid': 0.018, 'Natural Gas': 0.02, 
                      'Hybrid Gasoline': 0.025, 'Flex-Fuel': 0.015, 'Battery Electric': 0.3, 
                      'Plug-in Hybrid': 0.15, 'Hydrogen Fuel Cell': 0.2}

# Convert Duty variable to numerical (Light = 1, Heavy = 2)
df['Duty'] = df['Duty'].map({'Light': 1, 'Heavy': 2})

# Add a new column to the DataFrame to represent energy consumption per mile
df['Energy Consumption (kWh/mile)'] = df['Fuel'].map(energy_consumption)

# Calculate energy consumption per vehicle per year (kWh/year)
df['Energy Consumption (kWh/year)'] = df['Vehicles'] * df['Duty'] * df['Energy Consumption (kWh/mile)'] * 365

# Group the data by Make and Fuel, and sum the total energy consumption per year
grouped = df.groupby(['Make', 'Fuel'])['Energy Consumption (kWh/year)'].sum().unstack()

# Plot the total energy consumption by Make and Fuel using a stacked bar chart
ax = grouped.plot(kind='bar', stacked=True, figsize=(25, 6))
ax.set_ylabel('Total Energy Consumption (kWh/year)')
ax.legend(title='Fuel', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

# Count the number of light and heavy vehicles
duty_counts = df['Duty'].value_counts()

# Plot the results as a bar chart
duty_counts.plot(kind='bar')
plt.xlabel('Duty')
plt.ylabel('Number of Vehicles')
plt.title('Distribution of Vehicle Duty')
plt.show()
